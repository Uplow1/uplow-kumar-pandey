# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
categorical_cois = df.select_dtypes(include='object').columns

# %%
categorical_cois
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
for i in categorical_cois:
    print(df[i].unique)
# Out:
# <bound method Series.unique of 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object>
# <bound method Series.unique of 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object>
# <bound method Series.unique of 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object>
# <bound method Series.unique of 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object>
# <bound method Series.unique of 0           none
# 1      completed
# 2           none
# 3           none
# 4           none
#          ...
# 995    completed
# 996         none
# 997    completed
# 998    completed
# 999         none
# Name: test preparation course, Length: 1000, dtype: object>

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df['gender'])
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
count_test = df['test preparation course'].value_counts()
labels = df['test preparation course'].value_counts().index
plt.figure(figsize= (6,6))
plt.pie(count_test,labels=labels,autopct='%1.1f%%')
plt.legend(labels)
plt.show()

# %%
df['average_score']=(df['math score']+df['reading score']+df['writing score'])/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average_score
# 0        72.666667
# 1        82.333333
# 2        92.666667
# 3        49.333333
# 4        76.333333
# ..             ...
# 995      94.000000
# 996      57.333333
# 997      65.000000
# 998      74.333333
# 999      83.000000
#
# [1000 rows x 9 columns]

# %%
sns.scatterplot(x=df['average_score'],y=df['math score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='math score'>

# %%
sns.scatterplot(x=df['average_score'],y=df['reading score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='reading score'>

# %%
gender = {
    'male':1,
    'female':0
}

# %%
race = {
    'group A':0,
    'group B':1,
    'group C':2,
    'group D':3,
    'group E':4
}

# %%
df['gender']=df['gender'].map(gender)
df['race/ethnicity']=df['race/ethnicity'].map(race)

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0       NaN             NaN           bachelor's degree      standard
# 1       NaN             NaN                some college      standard
# 2       NaN             NaN             master's degree      standard
# 3       NaN             NaN          associate's degree  free/reduced
# 4       NaN             NaN                some college      standard
# ..      ...             ...                         ...           ...
# 995     NaN             NaN             master's degree      standard
# 996     NaN             NaN                 high school  free/reduced
# 997     NaN             NaN                 high school  free/reduced
# 998     NaN             NaN                some college      standard
# 999     NaN             NaN                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average_score
# 0        72.666667
# 1        82.333333
# 2        92.666667
# 3        49.333333
# 4        76.333333
# ..             ...
# 995      94.000000
# 996      57.333333
# 997      65.000000
# 998      74.333333
# 999      83.000000
#
# [1000 rows x 9 columns]

# %%
level ={
    "bachelor's degree":0
    ,'some collage':1
    ,"master's degree":3
    ,"associate's degree":3
    ,"high school":4
    ,"some high school":5
}

# %%
df['parental level of education']=df['parental level of education'].map(level)

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0       NaN             NaN           bachelor's degree      standard
# 1       NaN             NaN                some college      standard
# 2       NaN             NaN             master's degree      standard
# 3       NaN             NaN          associate's degree  free/reduced
# 4       NaN             NaN                some college      standard
# ..      ...             ...                         ...           ...
# 995     NaN             NaN             master's degree      standard
# 996     NaN             NaN                 high school  free/reduced
# 997     NaN             NaN                 high school  free/reduced
# 998     NaN             NaN                some college      standard
# 999     NaN             NaN                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average_score
# 0        72.666667
# 1        82.333333
# 2        92.666667
# 3        49.333333
# 4        76.333333
# ..             ...
# 995      94.000000
# 996      57.333333
# 997      65.000000
# 998      74.333333
# 999      83.000000
#
# [1000 rows x 9 columns]
